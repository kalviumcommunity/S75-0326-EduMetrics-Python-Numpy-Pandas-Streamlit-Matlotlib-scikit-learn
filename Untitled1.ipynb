# %%
import pandas as pd

data = {
    "Name": ["Jevin", "Arun", "Sam"],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Marks
# 0  Jevin     85
# 1   Arun     90
# 2    Sam     78
